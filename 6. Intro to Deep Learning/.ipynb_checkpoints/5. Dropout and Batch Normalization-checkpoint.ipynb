# %% [markdown]
# # 5-Droupout 과 Batch Normalization
#
# - 딥러닝의 세계는 생각보다 더 복잡함
# - 모델에 추가할 수 있는 레이어에는 수십 종류가 있고, 이 중 때때로 다양한 방식으로 모델에 도움이 될 수 있는 일부 기능을 추가하는 두 가지 종류의 특수 레이어를 설명하고자 함
#
# ## Dropout
#
# - 4장에서 훈련 데이터에서 네트워크 학습으로 과적합이 어떻게 발생하는지 배웠는데, 이를 방지하기 위해서 가중치의 특정조합에 의존하는 방식이다.
# - 즉 훈련의 모든 단계에서 layer의 입력 단위의 일부를 무작위로 삭제하여 네트워크가 훈련 데이터에서 이러한 가짜 패턴을 학습시키는 것을 더 어렵게 만든다.
# - 이는 가중치 패턴이 더 강력한 경향이 있는 광범위하고 일반적인 패턴을 찾게끔 해줌!!
#
#
# - 해당 그림은 dropout을 50%로 설정하였을 때, 50%의 확률인 2개를 무시하고 2개만 학습함 (이는 학습시 계속 무작위로 설정됨)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Batch Normalization
#
# - 배치 정규화는 느리거나 불안정한 훈련을 올바르게 하는데 도움이 된다.
# - **뉴럴 네트워크를 구축할때, StandardScaler 또는 MinMaxScaler 처럼 모든 데이터를 공통 규모로 배치하는 것이 좋다.**
#     - 그 이유는 SGD가 데이터가 생성하는 활성화의 크기에 비례하여 네트워크 가중치를 이동시키기 때문이다.
#     - 매우 다른 크기의 활성화를 생성하는 경향이 있는 기능은 불안정한 훈련 동작을 만듬!!
#
#
# - 네트워크에 들어가기 전에 정규화 하는 것이 좋다면, 네트워크 내부에서도 정규화하는 것이 더 좋을 것이다.
# - 이를 해주는 역할이 Batch Normalization layer이다.
#     1. 각 배치가 들어오는대로 살펴보고 먼저, 그것의 mean과 standard deviation으로 배치를 정규화한다.
#     2. 그 다음 두 개의 학습 가능한 크기의 rescaling parameter를 사용하여 데이터를 새로운 크기에 추가한다.
#     3. 실제로 Batchnorm은 입력에 대해 일종의 크기 조정을 수행한다.
#
# - 즉, 각 레이어마다 정규화 하는 레이어를 두어, 변형된 분포가 나오지 않도록 조절하게 하는 것!!!
# ![image.png](attachment:image.png)
#             배치 정규화는 간단히 말하자면 미니배치의 평균과 분산을 이용해서 정규화 한 뒤에, scale 및 shift 를 감마(γ) 값, 베타(β) 값을 통해 실행한다. 이 때 감마와 베타 값은 학습 가능한 변수이다. 즉, Backpropagation을 통해서 학습이 된다.
#
#             출처: https://eehoeskrap.tistory.com/430 [Enough is not enough]
#
# - 대부분 최적화 프로세스에 대한 지원으로 추가됨(예측성능에도도움 될 수 있음)
# - batchnorm이 있는 모델은 훈련을 완료하는데 더 적은 epoch가 필요한 경향이 있다!!

# %% [markdown]
# #### 실습1

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks

spotify = pd.read_csv('data/spotify.csv')

# 4장에서 진행하였던 전처리
X = spotify.copy().dropna()
y = X.pop('track_popularity')
artists = X['track_artist']

features_num = ['danceability', 'energy', 'key', 'loudness', 'mode',
                'speechiness', 'acousticness', 'instrumentalness',
                'liveness', 'valence', 'tempo', 'duration_ms']
features_cat = ['playlist_genre']

preprocessor = make_column_transformer(
    (StandardScaler(), features_num),
    (OneHotEncoder(), features_cat),
)

def group_split(X, y, group, train_size=0.75):
    splitter = GroupShuffleSplit(train_size=train_size)
    train, test = next(splitter.split(X, y, groups=group))
    return (X.iloc[train], X.iloc[test], y.iloc[train], y.iloc[test])

X_train, X_valid, y_train, y_valid = group_split(X, y, artists)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
y_train = y_train / 100
y_valid = y_valid / 100

input_shape = [X_train.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# Input shape: [18]

# %% [markdown]
# #### dropout을 추가한 모델 구축

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(1)
])

# %%
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
    verbose=0,
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()))
# Out:
# Minimum Validation Loss: 0.1922

# %% [markdown]
# #### 결과
#
# - train loss가 계속 감소하더라도 valid loss도 계속 최소값에 가까운 것을 확인가능!!
# - 즉 과적합을 방지했음을 확인 할 수 있다.(4장의 결과와 비교해보아도 차이가 남!!)

# %% [markdown]
# #### 실습2

# %%
import pandas as pd

concrete = pd.read_csv('data/concrete.csv')
df = concrete.copy()

df_train = df.sample(frac=0.7, random_state=0) #frac만큼 sample뽑음
df_valid = df.drop(df_train.index)

X_train = df_train.drop('CompressiveStrength', axis=1)
X_valid = df_valid.drop('CompressiveStrength', axis=1)
y_train = df_train['CompressiveStrength']
y_valid = df_valid['CompressiveStrength']

input_shape = [X_train.shape[1]]

# %%
model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=input_shape),
    layers.Dense(512, activation='relu'),    
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])
model.compile(
    optimizer='sgd', 
    loss='mae',
    metrics=['mae'],
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=64,
    epochs=100,
    verbose=1,
)

history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print(("Minimum Validation Loss: {:0.4f}").format(history_df['val_loss'].min()))
# Out:
# Epoch 1/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 2/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 3/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 4/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 5/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 6/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 7/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 8/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 9/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 10/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 11/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 12/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 13/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 14/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 15/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 16/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 17/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 18/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 19/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 20/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 21/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 22/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 23/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 24/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 25/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 26/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 27/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 28/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 29/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 30/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 31/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 32/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 33/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 34/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 35/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 36/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 37/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 38/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 39/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 40/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 41/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 42/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 43/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 44/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 45/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 46/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 47/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 48/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 49/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 50/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 51/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 52/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 53/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 54/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 55/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 56/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 57/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 58/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 59/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 60/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 61/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 62/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 63/100
# 12/12 [==============================] - 0s 11ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 64/100
# 12/12 [==============================] - 0s 10ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 65/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 66/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 67/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 68/100
# 12/12 [==============================] - 0s 10ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 69/100
# 12/12 [==============================] - 0s 9ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 70/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 71/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 72/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 73/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 74/100
# 12/12 [==============================] - 0s 5ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 75/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 76/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 77/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 78/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 79/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 80/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 81/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 82/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 83/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 84/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 85/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 86/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 87/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 88/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 89/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 90/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 91/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 92/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 93/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 94/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 95/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 96/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 97/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 98/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 99/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 100/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Minimum Validation Loss: nan

# %% [markdown]
# - 해당 데이터셋은 실패!! 왜??
#
# - Batch normalization layer가 도와줄 것이다

# %% [markdown]
# - **batch normalization layer 1층 추가**

# %%
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
#     layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
#     layers.BatchNormalization(),
    layers.Dense(1),
])

# %%
model.compile(
    optimizer='sgd',
    loss='mae',
    metrics=['mae'],
)
EPOCHS = 100
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=64,
    epochs=EPOCHS,
    verbose=1,
)

history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print(("Minimum Validation Loss: {:0.4f}").format(history_df['val_loss'].min()))
# Out:
# Minimum Validation Loss: 4.1973

# %% [markdown]
# - **batch normalization 3층 추가**

# %%
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(1),
])

# %%
model.compile(
    optimizer='sgd',
    loss='mae',
    metrics=['mae'],
)
EPOCHS = 100
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=64,
    epochs=EPOCHS,
    verbose=1,
)

history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print(("Minimum Validation Loss: {:0.4f}").format(history_df['val_loss'].min()))
# Out:
# Epoch 1/100
# 12/12 [==============================] - 0s 23ms/step - loss: 35.5297 - mae: 35.5297 - val_loss: 38.6792 - val_mae: 38.6792
# Epoch 2/100
# 12/12 [==============================] - 0s 8ms/step - loss: 35.1505 - mae: 35.1505 - val_loss: 37.5714 - val_mae: 37.5714
# Epoch 3/100
# 12/12 [==============================] - 0s 11ms/step - loss: 34.7506 - mae: 34.7506 - val_loss: 36.8996 - val_mae: 36.8996
# Epoch 4/100
# 12/12 [==============================] - 0s 7ms/step - loss: 34.3140 - mae: 34.3140 - val_loss: 36.3246 - val_mae: 36.3246
# Epoch 5/100
# 12/12 [==============================] - 0s 8ms/step - loss: 33.8239 - mae: 33.8239 - val_loss: 35.7647 - val_mae: 35.7647
# Epoch 6/100
# 12/12 [==============================] - 0s 8ms/step - loss: 33.2561 - mae: 33.2561 - val_loss: 35.1469 - val_mae: 35.1469
# Epoch 7/100
# 12/12 [==============================] - 0s 8ms/step - loss: 32.5865 - mae: 32.5865 - val_loss: 34.4301 - val_mae: 34.4301
# Epoch 8/100
# 12/12 [==============================] - 0s 7ms/step - loss: 31.7833 - mae: 31.7833 - val_loss: 33.5701 - val_mae: 33.5701
# Epoch 9/100
# 12/12 [==============================] - 0s 7ms/step - loss: 30.8094 - mae: 30.8094 - val_loss: 32.7307 - val_mae: 32.7307
# Epoch 10/100
# 12/12 [==============================] - 0s 9ms/step - loss: 29.6161 - mae: 29.6161 - val_loss: 31.4767 - val_mae: 31.4767
# Epoch 11/100
# 12/12 [==============================] - 0s 9ms/step - loss: 28.1534 - mae: 28.1534 - val_loss: 29.9649 - val_mae: 29.9649
# Epoch 12/100
# 12/12 [==============================] - 0s 8ms/step - loss: 26.3199 - mae: 26.3199 - val_loss: 28.0809 - val_mae: 28.0809
# Epoch 13/100
# 12/12 [==============================] - 0s 8ms/step - loss: 24.0660 - mae: 24.0660 - val_loss: 25.9575 - val_mae: 25.9575
# Epoch 14/100
# 12/12 [==============================] - 0s 8ms/step - loss: 21.2485 - mae: 21.2485 - val_loss: 23.2991 - val_mae: 23.2991
# Epoch 15/100
# 12/12 [==============================] - 0s 7ms/step - loss: 18.0616 - mae: 18.0616 - val_loss: 19.5065 - val_mae: 19.5065
# Epoch 16/100
# 12/12 [==============================] - 0s 7ms/step - loss: 14.6564 - mae: 14.6564 - val_loss: 16.4342 - val_mae: 16.4342
# Epoch 17/100
# 12/12 [==============================] - 0s 7ms/step - loss: 10.8992 - mae: 10.8992 - val_loss: 12.7552 - val_mae: 12.7552
# Epoch 18/100
# 12/12 [==============================] - 0s 9ms/step - loss: 8.7756 - mae: 8.7756 - val_loss: 11.1285 - val_mae: 11.1285
# Epoch 19/100
# 12/12 [==============================] - 0s 9ms/step - loss: 7.1030 - mae: 7.1030 - val_loss: 9.9466 - val_mae: 9.9466
# Epoch 20/100
# 12/12 [==============================] - 0s 8ms/step - loss: 6.2508 - mae: 6.2508 - val_loss: 11.2167 - val_mae: 11.2167
# Epoch 21/100
# 12/12 [==============================] - 0s 9ms/step - loss: 6.7490 - mae: 6.7490 - val_loss: 9.7830 - val_mae: 9.7830
# Epoch 22/100
# 12/12 [==============================] - 0s 8ms/step - loss: 6.2467 - mae: 6.2467 - val_loss: 9.4883 - val_mae: 9.4883
# Epoch 23/100
# 12/12 [==============================] - 0s 7ms/step - loss: 5.4330 - mae: 5.4330 - val_loss: 9.5666 - val_mae: 9.5666
# Epoch 24/100
# 12/12 [==============================] - 0s 7ms/step - loss: 5.6788 - mae: 5.6788 - val_loss: 7.7405 - val_mae: 7.7405
# Epoch 25/100
# 12/12 [==============================] - 0s 10ms/step - loss: 5.5953 - mae: 5.5953 - val_loss: 7.6809 - val_mae: 7.6809
# Epoch 26/100
# 12/12 [==============================] - 0s 9ms/step - loss: 5.3726 - mae: 5.3726 - val_loss: 8.8691 - val_mae: 8.8691
# Epoch 27/100
# 12/12 [==============================] - 0s 7ms/step - loss: 5.1546 - mae: 5.1546 - val_loss: 7.8369 - val_mae: 7.8369
# Epoch 28/100
# 12/12 [==============================] - 0s 8ms/step - loss: 5.0417 - mae: 5.0417 - val_loss: 8.0572 - val_mae: 8.0572
# Epoch 29/100
# 12/12 [==============================] - 0s 8ms/step - loss: 5.0309 - mae: 5.0309 - val_loss: 9.6690 - val_mae: 9.6690
# Epoch 30/100
# 12/12 [==============================] - 0s 8ms/step - loss: 4.6010 - mae: 4.6010 - val_loss: 9.0050 - val_mae: 9.0050
# Epoch 31/100
# 12/12 [==============================] - 0s 7ms/step - loss: 4.7033 - mae: 4.7033 - val_loss: 7.4932 - val_mae: 7.4932
# Epoch 32/100
# 12/12 [==============================] - 0s 7ms/step - loss: 4.2689 - mae: 4.2689 - val_loss: 7.4711 - val_mae: 7.4711
# Epoch 33/100
# 12/12 [==============================] - 0s 8ms/step - loss: 4.6290 - mae: 4.6290 - val_loss: 7.9742 - val_mae: 7.9742
# Epoch 34/100
# 12/12 [==============================] - 0s 7ms/step - loss: 4.6206 - mae: 4.6206 - val_loss: 7.0337 - val_mae: 7.0337
# Epoch 35/100
# 12/12 [==============================] - 0s 7ms/step - loss: 4.4160 - mae: 4.4160 - val_loss: 7.4268 - val_mae: 7.4268
# Epoch 36/100
# 12/12 [==============================] - 0s 8ms/step - loss: 4.3886 - mae: 4.3886 - val_loss: 6.6293 - val_mae: 6.6293
# Epoch 37/100
# 12/12 [==============================] - 0s 8ms/step - loss: 4.1010 - mae: 4.1010 - val_loss: 6.8956 - val_mae: 6.8956
# Epoch 38/100
# 12/12 [==============================] - 0s 9ms/step - loss: 4.0808 - mae: 4.0808 - val_loss: 6.6012 - val_mae: 6.6012
# Epoch 39/100
# 12/12 [==============================] - 0s 16ms/step - loss: 4.1639 - mae: 4.1639 - val_loss: 6.4751 - val_mae: 6.4751
# Epoch 40/100
# 12/12 [==============================] - 0s 14ms/step - loss: 4.3351 - mae: 4.3351 - val_loss: 6.4262 - val_mae: 6.4262
# Epoch 41/100
# 12/12 [==============================] - 0s 13ms/step - loss: 4.0491 - mae: 4.0491 - val_loss: 6.6591 - val_mae: 6.6591
# Epoch 42/100
# 12/12 [==============================] - 0s 9ms/step - loss: 4.3064 - mae: 4.3064 - val_loss: 6.0217 - val_mae: 6.0217
# Epoch 43/100
# 12/12 [==============================] - 0s 8ms/step - loss: 4.2321 - mae: 4.2321 - val_loss: 5.2025 - val_mae: 5.2025
# Epoch 44/100
# 12/12 [==============================] - 0s 7ms/step - loss: 4.0086 - mae: 4.0086 - val_loss: 6.0730 - val_mae: 6.0730
# Epoch 45/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.8414 - mae: 3.8414 - val_loss: 5.4170 - val_mae: 5.4170
# Epoch 46/100
# 12/12 [==============================] - 0s 9ms/step - loss: 4.3036 - mae: 4.3036 - val_loss: 6.0167 - val_mae: 6.0167
# Epoch 47/100
# 12/12 [==============================] - 0s 13ms/step - loss: 4.2297 - mae: 4.2297 - val_loss: 5.9361 - val_mae: 5.9361
# Epoch 48/100
# 12/12 [==============================] - 0s 9ms/step - loss: 4.1056 - mae: 4.1056 - val_loss: 5.9668 - val_mae: 5.9668
# Epoch 49/100
# 12/12 [==============================] - 0s 8ms/step - loss: 4.0256 - mae: 4.0256 - val_loss: 5.0203 - val_mae: 5.0203
# Epoch 50/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.7979 - mae: 3.7979 - val_loss: 5.3207 - val_mae: 5.3207
# Epoch 51/100
# 12/12 [==============================] - 0s 8ms/step - loss: 4.0746 - mae: 4.0746 - val_loss: 5.8801 - val_mae: 5.8801
# Epoch 52/100
# 12/12 [==============================] - 0s 7ms/step - loss: 4.0465 - mae: 4.0465 - val_loss: 6.1646 - val_mae: 6.1646
# Epoch 53/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.8100 - mae: 3.8100 - val_loss: 4.8723 - val_mae: 4.8723
# Epoch 54/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.6676 - mae: 3.6676 - val_loss: 4.7700 - val_mae: 4.7700
# Epoch 55/100
# 12/12 [==============================] - 0s 10ms/step - loss: 3.5717 - mae: 3.5717 - val_loss: 4.8767 - val_mae: 4.8767
# Epoch 56/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.9611 - mae: 3.9611 - val_loss: 4.8586 - val_mae: 4.8586
# Epoch 57/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.7305 - mae: 3.7305 - val_loss: 5.4087 - val_mae: 5.4087
# Epoch 58/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4634 - mae: 3.4634 - val_loss: 5.1310 - val_mae: 5.1310
# Epoch 59/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.7632 - mae: 3.7632 - val_loss: 5.1047 - val_mae: 5.1047
# Epoch 60/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.5626 - mae: 3.5626 - val_loss: 4.8527 - val_mae: 4.8527
# Epoch 61/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.6759 - mae: 3.6759 - val_loss: 4.8892 - val_mae: 4.8892
# Epoch 62/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.3813 - mae: 3.3813 - val_loss: 4.7484 - val_mae: 4.7484
# Epoch 63/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4844 - mae: 3.4844 - val_loss: 4.6475 - val_mae: 4.6475
# Epoch 64/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.5672 - mae: 3.5672 - val_loss: 4.5445 - val_mae: 4.5445
# Epoch 65/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.6960 - mae: 3.6960 - val_loss: 5.5639 - val_mae: 5.5639
# Epoch 66/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.6560 - mae: 3.6560 - val_loss: 5.5060 - val_mae: 5.5060
# Epoch 67/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.8786 - mae: 3.8786 - val_loss: 4.3754 - val_mae: 4.3754
# Epoch 68/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.8196 - mae: 3.8196 - val_loss: 5.2887 - val_mae: 5.2887
# Epoch 69/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.8066 - mae: 3.8066 - val_loss: 5.1009 - val_mae: 5.1009
# Epoch 70/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.5013 - mae: 3.5013 - val_loss: 4.6501 - val_mae: 4.6501
# Epoch 71/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.7090 - mae: 3.7090 - val_loss: 4.5511 - val_mae: 4.5511
# Epoch 72/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.5986 - mae: 3.5986 - val_loss: 4.1928 - val_mae: 4.1928
# Epoch 73/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.3039 - mae: 3.3039 - val_loss: 4.5022 - val_mae: 4.5022
# Epoch 74/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4648 - mae: 3.4648 - val_loss: 5.0733 - val_mae: 5.0733
# Epoch 75/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.8689 - mae: 3.8689 - val_loss: 5.4062 - val_mae: 5.4062
# Epoch 76/100
# 12/12 [==============================] - 0s 8ms/step - loss: 4.0226 - mae: 4.0226 - val_loss: 4.5850 - val_mae: 4.5850
# Epoch 77/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.4385 - mae: 3.4385 - val_loss: 6.0150 - val_mae: 6.0150
# Epoch 78/100
# 12/12 [==============================] - 0s 6ms/step - loss: 3.5398 - mae: 3.5398 - val_loss: 5.1328 - val_mae: 5.1328
# Epoch 79/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4665 - mae: 3.4665 - val_loss: 5.0835 - val_mae: 5.0835
# Epoch 80/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.3384 - mae: 3.3384 - val_loss: 5.5916 - val_mae: 5.5916
# Epoch 81/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.1935 - mae: 3.1935 - val_loss: 5.1251 - val_mae: 5.1251
# Epoch 82/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.6642 - mae: 3.6642 - val_loss: 4.9536 - val_mae: 4.9536
# Epoch 83/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.5940 - mae: 3.5940 - val_loss: 4.3518 - val_mae: 4.3518
# Epoch 84/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.2632 - mae: 3.2632 - val_loss: 4.8132 - val_mae: 4.8132
# Epoch 85/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.5616 - mae: 3.5616 - val_loss: 4.3862 - val_mae: 4.3862
# Epoch 86/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.2464 - mae: 3.2464 - val_loss: 5.3745 - val_mae: 5.3745
# Epoch 87/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.4674 - mae: 3.4674 - val_loss: 5.5970 - val_mae: 5.5970
# Epoch 88/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4832 - mae: 3.4832 - val_loss: 4.1318 - val_mae: 4.1318
# Epoch 89/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.3044 - mae: 3.3044 - val_loss: 4.8220 - val_mae: 4.8220
# Epoch 90/100
# 12/12 [==============================] - 0s 6ms/step - loss: 3.2481 - mae: 3.2481 - val_loss: 4.9702 - val_mae: 4.9702
# Epoch 91/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.3665 - mae: 3.3665 - val_loss: 3.8246 - val_mae: 3.8246
# Epoch 92/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.3681 - mae: 3.3681 - val_loss: 4.3567 - val_mae: 4.3567
# Epoch 93/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.5127 - mae: 3.5127 - val_loss: 5.2941 - val_mae: 5.2941
# Epoch 94/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.7822 - mae: 3.7822 - val_loss: 4.1492 - val_mae: 4.1492
# Epoch 95/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.2711 - mae: 3.2711 - val_loss: 4.8275 - val_mae: 4.8275
# Epoch 96/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4492 - mae: 3.4492 - val_loss: 4.0800 - val_mae: 4.0800
# Epoch 97/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.3816 - mae: 3.3816 - val_loss: 4.6130 - val_mae: 4.6130
# Epoch 98/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.3437 - mae: 3.3437 - val_loss: 4.4768 - val_mae: 4.4768
# Epoch 99/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4029 - mae: 3.4029 - val_loss: 4.6565 - val_mae: 4.6565
# Epoch 100/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.2517 - mae: 3.2517 - val_loss: 4.4759 - val_mae: 4.4759
# Minimum Validation Loss: 3.8246
